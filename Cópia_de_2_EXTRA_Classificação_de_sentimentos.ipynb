# %% [markdown]
# <a href="https://colab.research.google.com/github/EveFeliciano/machinelearning/blob/main/C%C3%B3pia_de_2_EXTRA_Classifica%C3%A7%C3%A3o_de_sentimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Criando uma base numa lista e transformando num DataFrame

# %%
#Importando uma biblioteca de Processamento de Linguaguem natural
import nltk

# %%
#base criada na mão, com frases aleatórias
base = [('não precisei pagar o ingresso','alegria'),
('se eu ajeitar tudo fica bem','alegria'),
('minha fortuna ultrapassa a sua','alegria'),
('sou muito afortunado','alegria'),
('e benefico para todos esta nova medida','alegria'),
('ficou lindo','alegria'),
('achei esse sapato muito simpático','alegria'),
('estou ansiosa pela sua chegada','alegria'),
('congratulações pelo seu aniversário','alegria'),
('delicadamente ele a colocou para dormir','alegria'),
('a musica e linda','alegria'),
('sem musica eu não vivo','alegria'),
('conclui uma tarefa muito difícil','alegria'),
('conclui minha graduação','alegria'),
('estou muito contente com tudo','alegria'),
('eu confio em você','alegria'),
('e um prazer conhecê-lo','alegria'),
('o coleguismo de vocês e animador','alegria'),
('estou aproveitando as ferias','alegria'),
('vamos aproveitar as ferias','alegria'),
('e muito divertido este jogo','alegria'),
('vamos ter muita diversão','alegria'),
('não achei que me divertiria tanto assim','alegria'),
('vou consentir o orçamento ao cliente','alegria'),
('com o consentimento dos meus pais podemos nos casar','alegria'),
('eu adorei este perfume','alegria'),
('sua bondade e cativante','alegria'),
('estou despreocupada','alegria'),
('não me preocupo com o que aconteceu','alegria'),
('me sinto completamente segura','alegria'),
('estimo muito o seu trabalho','alegria'),
('somos estimados por nossa família','alegria'),
('concretizamos nossa ideia','alegria'),
('nosso ideal foi alcançado','alegria'),
('estamos muito felizes juntos','alegria'),
('estou tão animada com os preparativos para o casamento','alegria'),
('você será muito amado meu filho','alegria'),
('os apaixonados são maravilhosos','alegria'),
('agradeço imensamente o seu apoio nestes dias','alegria'),
('esta comida me parece muito atraente','alegria'),
('você me completa','alegria'),
('poderemos completar o projeto hoje!','alegria'),
('estamos namorando','alegria'),
('estou namorando este vestido a um tempo','alegria'),
('pude comprar meu celular hoje','alegria'),
('e um deleite poder compartilhar minhas vitórias','alegria'),
('ela e um boa garota','alegria'),
('estivemos em um ótimo show','alegria'),
('este trabalho e agradável','alegria'),
('gosto de ficar no seu aconchego','alegria'),
('fiz a adesão ao curso hoje','alegria'),
('eu sou admirada por muitos','alegria'),
('adoro como você e','alegria'),
('adoro seu cabelo macio','alegria'),
('adoro a cor dos seus olhos','alegria'),
('somo tão amáveis um com o outro','alegria'),
('sinto uma grande afeição por ele','alegria'),
('quero agradar meus filhos','alegria'),
('me sinto completamente amado','alegria'),
('eu amo você','alegria'),
('que grande alivio','alegria'),
('a dor esta amenizando finalmente','alegria'),
('acho que me apaixonei','alegria'),
('amar e maravilhoso','alegria'),
('estou me sentindo muito animada','alegria'),
('me sinto muito bem hoje','alegria'),
('como o luar e belo','alegria'),
('o dia esta muito bonito','alegria'),
('nossa como sou afortunado','alegria'),
('as maravilhas do mundo','alegria'),
('recebi muito carinho hoje do meus colegas','alegria'),
('estou me sentindo reconfortada hoje','alegria'),
('e muito bom estar com os amigos','alegria'),
('estou muito contente com o resultado dos testes','alegria'),
('essa pintura esta bem brilhante','alegria'),
('temos água em abundancia','alegria'),
('que roupa delicada','alegria'),
('você e um grande comediante','alegria'),
('que bondade a sua em vir aqui','alegria'),
('o amor e lindo','alegria'),
('nossa amizade vai durar para sempre','alegria'),
('estou eufórica com a noticia','alegria'),
('ele e realmente fiel a mim','alegria'),
('vou dar uma grande festa para comemorar meu aniversário','alegria'),
('graças a deus que eu enxerguei o certo','alegria'),
('essa e a melhor escolhas de todas','alegria'),
('o mais incrível e você minha bela','alegria'),
('e tão engraçado tentar explicar','alegria'),
('e emocionante estar neste lugar','alegria'),
('estou cativada pelo seu olhar','alegria'),
('estou loucamente apaixonada','alegria'),
('eu nunca tive duvidas','alegria'),
('estou rodeada pelo seu abraço','alegria'),
('eu vejo estrelas pelo caminho','alegria'),
('eu sinto o sol sempre que você esta por perto','alegria'),
('eu estou sorrindo de orelha a orelha','alegria'),
('isso vale a pena','alegria'),
('finalmente você colocou meu amor em primeiro lugar','alegria'),
('nós dançamos noite adentro','alegria'),
('seu amor e brilhante','alegria'),
('toquei muitos corações durante o meu caminho','alegria'),
('eu serei sua amiga e companheira','alegria'),
('você me traz de volta a vida','alegria'),
('você e como um sonho doce','alegria'),
('adoro este doce de frutas','alegria'),
('meu suco favorito','alegria'),
('estou agradecida pela ajuda','alegria'),
('e um enorme prazer ter você em nossa equipe','alegria'),
('trabalhar em equipe e o melhor','alegria'),
('me sinto flutuando no ar','alegria'),
('a brisa esta agradável hoje','alegria'),
('ótimo e compatível','alegria'),
('somos compatíveis um com o outro','alegria'),
('o órgão e compatível com o paciente','alegria'),
('estou contente fui aceita na faculdade','alegria'),
('fui aprovada no meu exame','alegria'),
('fui beneficiada pela minha empresa','alegria'),
('eu sou muito cativante','alegria'),
('estou contente com o apoio','alegria'),
('como este lugar e confortável','alegria'),
('e bom estar quente neste frio','alegria'),
('um elogio nunca e demais','alegria'),
('vou te chamar para comemorar','alegria'),
('e desejável a sua presença em nossa apresentação','alegria'),
('sou muito grata a você','alegria'),
('me dedico muito naquilo que faço','alegria'),
('estou completamente apaixonada ','alegria'),
('vamos agitar essa noite ','alegria'),
('você significa muito para mim','alegria'),
('vamos agir sem preconceitos e julgamentos','alegria'),
('finalmente completei a minha coleção, maravilhoso','alegria'),
('eu sou sua rainha ','alegria'),
('satisfatoriamente eu anuncio o vencedor dos jogos','alegria'),
('você me atrai facilmente ','alegria'),
('aquele rapaz e extremamente atraente','alegria'),
('sinto-me viva ','alegria'),
('sinto-me em paz ','alegria'),
('estamos tendo muito lucro','alegria'),
('muito bem esta tudo em ordem agora ','alegria'),
('podemos arrumar um emprego juntos ','alegria'),
('a arrumação esta terminada, que alívio','alegria'),
('o câncer e benigno ','alegria'),
('o amor e abundante','alegria'),
('vamos ser caridosos este natal','alegria'),
('com todo esse charme você irá atrair a todos','alegria'),
('nossa como você e charmoso querido ','alegria'),
('sou querida pelos meu amigos','alegria'),
('seja cuidadoso com os meus sentimentos','alegria'),
('estou comovido com tamanha caridade','alegria'),
('um chá quente e reconfortante','alegria'),
('que alegria ter vocês aqui ','alegria'),
('vamos aplaudir o vencedor ','alegria'),
('palmas para a aniversariante','alegria'),
('desejo a você tudo de bom','alegria'),
('hora de apreciar um bom vinho','alegria'),
('aprecio sua presença em minha escola','alegria'),
('anseio por seus próximos trabalhos','alegria'),
('maravilhoso jogo amistoso','alegria'),
('e ótimo que os ânimos tenham se apaziguado','alegria'),
('concretizei finalmente meu sonho','alegria'),
('A alegria de ver o nascer do sol é indescritível','alegria'),
('Receber boas notícias sempre me enche de alegria.'),
('Ver meu time ganhar me enche de alegria e orgulho.'),
('A alegria de estar com a família é incomparável.'),
('O sorriso de uma criança é a maior fonte de alegria.'),
('Encontrar um velho amigo me enche de alegria.'),
('A conquista de um objetivo é motivo de grande alegria.'),
('O amor verdadeiro traz uma alegria profunda ao coração.'),
('A alegria de explorar lugares novos é emocionante.'),
('Comemorar um aniversário é uma fonte de alegria.'),
('A alegria de superar desafios é gratificante.'),
('O sucesso de alguém que amamos traz alegria genuína.'),
('O riso de uma pessoa querida é contagiante.'),
('O primeiro beijo é um momento de alegria inigualável.'),
('A música tem o poder de trazer alegria instantaneamente.'),
('A alegria de receber um elogio é imensurável.'),
('A liberdade de expressão traz uma sensação de alegria.'),
('A simplicidade da vida cotidiana pode ser uma fonte de alegria.'),
('A alegria de encontrar algo perdido é inestimável.'),
('A natureza oferece momentos de alegria inigualável.'),
('Consegui um aumento no meu salário!', 'alegria'),
('Recebi uma notícia maravilhosa hoje de manhã.', 'alegria'),
('Meu time ganhou o campeonato, estou tão feliz!', 'alegria'),
('O nascimento de um bebê é sempre um momento de alegria.', 'alegria'),
('Comemorar meu aniversário com amigos me deixou alegre.', 'alegria'),
('Visitar um parque de diversões sempre me traz alegria.', 'alegria'),
('Estou tão animado para as férias de verão!', 'alegria'),
('O sorriso de uma criança é contagiante.', 'alegria'),
('Reencontrei um amigo querido que não via há anos.', 'alegria'),
('Fui promovido no trabalho, estou radiante!', 'alegria'),
('Receber flores inesperadamente me deixou feliz.', 'alegria'),
('Concluí meu projeto com sucesso, estou aliviado.', 'alegria'),
('Ganhei um concurso de talentos, estou extasiado!', 'alegria'),
('O pôr do sol na praia é sempre um espetáculo incrível.', 'alegria'),
('A alegria de aprender algo novo é empolgante.', 'alegria'),
('Amar e ser amado é uma fonte constante de alegria.', 'alegria'),
('Terminar um livro fascinante me deixa feliz.', 'alegria'),
('A alegria de cozinhar uma refeição deliciosa é gratificante.', 'alegria'),
('A vista de uma montanha coberta de neve é deslumbrante.', 'alegria'),
('Um abraço apertado de um ente querido é sempre reconfortante.', 'alegria'),
('A alegria de viajar para um lugar novo é emocionante.', 'alegria'),
('O cheiro de bolo assando no forno é irresistível.', 'alegria'),
('Comemorar uma vitória com a equipe é sempre alegre.', 'alegria'),
('A música tem o poder de levantar meu espírito.', 'alegria'),
('Receber um elogio pelo meu trabalho me enche de alegria.', 'alegria'),
('A alegria de ver um entardecer incrível é indescritível.', 'alegria'),
('Ganhar um prêmio foi uma surpresa maravilhosa!', 'alegria'),
('A alegria de nadar em águas cristalinas é relaxante.', 'alegria'),
('A amizade verdadeira é uma fonte constante de alegria.', 'alegria'),
('O nascer do sol no campo é uma visão revigorante.', 'alegria'),
('A alegria de ver meu artista favorito ao vivo é inesquecível.', 'alegria'),
('Realizei meu sonho de infância, estou nas nuvens!', 'alegria'),
('Ver meu time vencer no último minuto foi emocionante.', 'alegria'),
('A alegria de um passeio de bicicleta em um dia ensolarado é única.', 'alegria'),
('A surpresa de um presente inesperado me deixou radiante.', 'alegria'),
('A alegria de ajudar alguém em necessidade é gratificante.', 'alegria'),
('Fui aceito na universidade dos meus sonhos, estou extasiado!', 'alegria'),
('A alegria de estar cercado pela natureza é indescritível.', 'alegria'),
('A simplicidade de um piquenique no parque me traz alegria.', 'alegria'),
('A alegria de explorar um novo país é emocionante.', 'alegria'),
('Ver o arco-íris depois da chuva é sempre mágico.', 'alegria'),
('A alegria de receber uma carta de um amigo distante é única.', 'alegria'),
('O abraço de um ente querido é o melhor remédio.', 'alegria'),
('A alegria de receber um elogio inesperado é contagiante.', 'alegria'),
('O sucesso de um projeto árduo me deixa alegre.', 'alegria'),
('A sensação de paz ao meditar me traz alegria interior.', 'alegria'),
('Receber uma ligação de um amigo querido me deixou feliz.', 'alegria'),
('A alegria de encontrar algo perdido há muito tempo é inestimável.', 'alegria'),
('Ver meu filho dar seus primeiros passos foi emocionante.', 'alegria'),
('A alegria de vencer um desafio é indescritível.', 'alegria'),
('Comemorar a formatura com amigos é alegria pura.', 'alegria'),
('A alegria de estar com a família no Natal é incomparável.', 'alegria'),
('Ver meu filme favorito pela centésima vez me faz feliz.', 'alegria'),
('O sorriso de um estranho na rua me aqueceu o coração.', 'alegria'),
('A alegria de resolver um quebra-cabeça difícil é gratificante.', 'alegria'),
('A sensação de liberdade ao dirigir sem destino é alegre.', 'alegria'),
('A alegria de ver a cidade iluminada durante as festas é mágica.', 'alegria'),
('Agradecer pelas pequenas coisas na vida traz alegria profunda.', 'alegria'),
('A alegria de fazer uma viagem espontânea é emocionante.', 'alegria'),
('Ver meu animal de estimação correr de felicidade é contagiante.', 'alegria'),
('A alegria de terminar um projeto artístico é inspiradora.', 'alegria'),
('A sensação de realização após um treino intenso traz alegria.', 'alegria'),
('A alegria de experimentar uma comida deliciosa é única.', 'alegria'),
('Comemorar a vitória do meu time é sempre alegre.', 'alegria'),
('A alegria de ver o sorriso de um idoso é reconfortante.', 'alegria'),
('O amor verdadeiro traz alegria profunda ao coração.', 'alegria'),
('A alegria de ver a felicidade dos outros é um ato de amor.', 'alegria'),
('A sensação de alívio após superar um desafio é alegre.', 'alegria'),
('Receber uma massagem relaxante me deixa em êxtase.', 'alegria'),
('A alegria de um dia ensolarado é contagiante.', 'alegria'),
('A sensação de paz em um jardim tranquilo é alegre.', 'alegria'),
('A alegria de se apaixonar é indescritível.', 'alegria'),
('A sensação de bem-estar após um banho quente é alegre.', 'alegria'),
('A alegria de receber uma lembrança de infância é emocionante.', 'alegria'),
('A gratidão pela vida me enche de alegria.', 'alegria'),
('O abraço apertado de um amigo me deixa alegre.', 'alegria'),
('A alegria de receber um presente surpresa é inestimável.', 'alegria'),
('A alegria de ouvir uma música favorita é instantânea.', 'alegria'),
('Comemorar a vitória do meu time é sempre alegre.', 'alegria'),
('A alegria de ver meu artista favorito ao vivo é inesquecível.', 'alegria'),
('A alegria de nadar em águas cristalinas é relaxante.', 'alegria'),
('A amizade verdadeira é uma fonte constante de alegria.', 'alegria'),
('O nascer do sol no campo é uma visão revigorante.', 'alegria'),
('A alegria de aprender algo novo é empolgante.', 'alegria'),
('Amar e ser amado é uma fonte constante de alegria.', 'alegria'),
('Terminar um livro fascinante me deixa feliz.', 'alegria'),
('A alegria de cozinhar uma refeição deliciosa é gratificante.', 'alegria'),
('A vista de uma montanha coberta de neve é deslumbrante.', 'alegria'),
('Um abraço apertado de um ente querido é sempre reconfortante.', 'alegria'),
('A alegria de viajar para um lugar novo é emocionante.', 'alegria'),
('O cheiro de bolo assando no forno é irresistível.', 'alegria'),
('Comemorar uma vitória com a equipe é sempre alegre.', 'alegria'),
('A música tem o poder de levantar meu espírito.', 'alegria'),
('Receber um elogio pelo meu trabalho me enche de alegria.', 'alegria'),
('A alegria de ver um entardecer incrível é indescritível.', 'alegria'),
('Ganhar um prêmio foi uma surpresa maravilhosa!', 'alegria'),
('A alegria de nadar em águas cristalinas é relaxante.', 'alegria'),
('A amizade verdadeira é uma fonte constante de alegria.', 'alegria'),
('O nascer do sol no campo é uma visão revigorante.', 'alegria'),
('A alegria de ver meu artista favorito ao vivo é inesquecível.', 'alegria'),
('Realizei meu sonho de infância, estou nas nuvens!', 'alegria'),
('Ver meu time vencer no último minuto foi emocionante.', 'alegria'),
('A alegria de um passeio de bicicleta em um dia ensolarado é única.', 'alegria'),
('A surpresa de um presente inesperado me deixou radiante.', 'alegria'),
('A alegria de ajudar alguém em necessidade é gratificante.', 'alegria'),
('Fui aceito na universidade dos meus sonhos, estou extasiado!', 'alegria'),
('A alegria de estar cercado pela natureza é indescritível.', 'alegria'),
('A simplicidade de um piquenique no parque me traz alegria.', 'alegria'),
('A alegria de explorar um novo país é emocionante.', 'alegria'),
('Ver o arco-íris depois da chuva é sempre mágico.', 'alegria'),
('A alegria de receber uma carta de um amigo distante é única.', 'alegria'),
('O abraço de um ente querido é o melhor remédio.', 'alegria'),
('A alegria de receber um elogio inesperado é contagiante.', 'alegria'),
('O sucesso de um projeto árduo me deixa alegre.', 'alegria'),
('A sensação de paz ao meditar me traz alegria'),
('Estou com medo do que o futuro reserva.', 'medo'),
('O escuro me assusta profundamente.', 'medo'),
('O som de passos na rua à noite me deixa nervoso.', 'medo'),
('Fui surpreendido por um barulho estranho no porão.', 'medo'),
('Sinto medo de voar de avião.', 'medo'),
('A sensação de estar sendo observado me apavora.', 'medo'),
('Estou com medo de fazer a apresentação no trabalho.', 'medo'),
('O barulho de trovões me faz tremer de medo.', 'medo'),
('O filme de terror me deu pesadelos.', 'medo'),
('Perder meu emprego é um pensamento que me aterroriza.', 'medo'),
('Sinto medo de altura quando estou em lugares altos.', 'medo'),
('A escuridão da floresta me enche de medo.', 'medo'),
('A sensação de estar sozinho em casa me deixa apreensivo.', 'medo'),
('O medo de falhar me impede de tentar coisas novas.', 'medo'),
('Sair de casa durante uma tempestade me deixa ansioso.', 'medo'),
('O medo de cobras é uma fobia que tenho.', 'medo'),
('Sinto medo de multidões em lugares lotados.', 'medo'),
('O medo de aranhas me faz gritar de pavor.', 'medo'),
('A ideia de um acidente de carro me deixa tenso.', 'medo'),
('Ouvir histórias de fantasmas me deixa arrepiado.', 'medo'),
('A sensação de estar perdido em um lugar desconhecido é assustadora.', 'medo'),
('A incerteza do que o futuro reserva me deixa ansioso.', 'medo'),
('Sinto medo quando ouço ruídos estranhos na casa à noite.', 'medo'),
('A sensação de estar sendo seguido é apavorante.', 'medo'),
('Tenho medo de nadar em águas profundas.', 'medo'),
('O medo de cobranças financeiras me causa insônia.', 'medo'),
('A ideia de um desastre natural me deixa inquieto.', 'medo'),
('Sinto medo de andar sozinho à noite na cidade.', 'medo'),
('A sensação de estar encurralado é aterradora.', 'medo'),
('O medo de perder entes queridos me mantém acordado à noite.', 'medo'),
('Sinto medo de insetos rastejantes.', 'medo'),
('O medo de um ataque de pânico me paralisa.', 'medo'),
('A ideia de estar em um lugar assombrado me apavora.', 'medo'),
('O medo de agulhas me impede de fazer exames médicos.', 'medo'),
('Sinto medo de confrontar pessoas em conflitos.', 'medo'),
('A sensação de ser perseguido me deixa em estado de alerta.', 'medo'),
('Tenho medo de dirigir em rodovias movimentadas.', 'medo'),
('O medo de ficar doente me deixa ansioso.', 'medo'),
('A ideia de um ataque terrorista me deixa nervoso.', 'medo'),
('Sinto medo de tomar decisões importantes.', 'medo'),
('O medo de fantasmas me faz evitar lugares assombrados.', 'medo'),
('A sensação de estar em um elevador lotado é angustiante.', 'medo'),
('Tenho medo de andar de montanha-russa.', 'medo'),
('O medo de ser julgado pelos outros me paralisa.', 'medo'),
('A ideia de um incêndio em casa me deixa preocupado.', 'medo'),
('Sinto medo de enfrentar situações de confronto.', 'medo'),
('A sensação de estar perdido em um labirinto é aterradora.', 'medo'),
('O medo de aranhas me faz evitar sótãos.', 'medo'),
('Tenho medo de altura quando estou em prédios altos.', 'medo'),
('O medo de falar em público me deixa ansioso.', 'medo'),
('Sinto medo de ser atacado por animais selvagens.', 'medo'),
('A ideia de um ataque cibernético me deixa preocupado.', 'medo'),
('A sensação de estar preso em um espaço pequeno é sufocante.', 'medo'),
('Tenho medo de enfrentar meu chefe em uma discussão.', 'medo'),
('O medo de ter um acidente de avião me faz evitar voar.', 'medo'),
('Sinto medo de tempestades elétricas.', 'medo'),
('A ideia de uma invasão alienígena me deixa apavorado.', 'medo'),
('O medo de falhar em um exame importante me causa insônia.', 'medo'),
('A sensação de estar em uma floresta escura é assustadora.', 'medo'),
('Tenho medo de fantasmas desde a infância.', 'medo'),
('O medo de andar sozinho à noite na rua me deixa ansioso.', 'medo'),
('Sinto medo de situações de confronto físico.', 'medo'),
('A ideia de um desastre natural iminente me deixa tenso.', 'medo'),
('A sensação de estar em um lugar abandonado é arrepiante.', 'medo'),
('Tenho medo de ver sangue, mesmo que seja apenas um corte pequeno.', 'medo'),
('O medo de ser assaltado em lugares escuros me deixa apreensivo.', 'medo'),
('Sinto medo de ficar sozinho em casa durante uma tempestade.', 'medo'),
('A ideia de estar em um local mal-assombrado me apavora.', 'medo'),
('O medo de enfermidades graves me mantém acordado à noite.', 'medo'),
('A sensação de estar em um espaço apertado me causa claustrofobia.', 'medo'),
('Tenho medo de ver vultos no escuro.', 'medo'),
('O medo de perder o emprego me deixa inquieto.', 'medo'),
('Sinto medo de altura quando estou em lugares altos.', 'medo'),
('A ideia de um acidente de carro me deixa tenso.', 'medo'),
('A sensação de que algo está escondido sob a cama é assustadora.', 'medo'),
('Tenho medo de ficar preso em um elevador.', 'medo'),
('O medo de tomar decisões erradas me paralisa.', 'medo'),
('Sinto medo de enfrentar situações de confronto verbal.', 'medo'),
('A ideia de um ataque de zumbis me deixa nervoso.', 'medo'),
('O medo de enfrentar uma tempestade no mar me faz evitar passeios de barco.', 'medo'),
('A sensação de estar em um local deserto é assustadora.', 'medo'),
('Tenho medo de ter pesadelos à noite.', 'medo'),
('O medo de ser traído por alguém próximo me deixa apreensivo.', 'medo'),
('Sinto medo de agulhas em procedimentos médicos.', 'medo'),
('A ideia de um acidente de avião me deixa nervoso.', 'medo'),
('O medo de não ser aceito pelos outros me causa ansiedade.', 'medo'),
('A sensação de que algo está escondido no armário me apavora.', 'medo'),
('Tenho medo de insetos venenosos.', 'medo'),
('O medo de falhar em um teste importante me deixa tenso.', 'medo'),
('Sinto medo de ser assombrado por espíritos.', 'medo'),
('A ideia de um ataque de animais selvagens me deixa preocupado.', 'medo'),
('O medo de contrair uma doença grave me causa insônia.', 'medo'),
('A sensação de estar sendo perseguido é apavorante.', 'medo'),
('Tenho medo de dirigir à noite.', 'medo'),
('O medo de ficar trancado em um banheiro público me deixa ansioso.', 'medo'),
('Sinto medo de confrontar meus medos mais profundos.', 'medo'),
('A ideia de estar em um hospital me faz tremer de medo.', 'medo'),
('O medo de ser alvo de um crime me deixa inquieto.', 'medo'),
('A sensação de estar sendo vigiado é aterradora.', 'medo'),
('Tenho medo de ser mordido por animais.', 'medo'),
('O medo de ser vítima de um sequestro me causa ansiedade.', 'medo'),
('Sinto medo de ser atacado por estranhos na rua.', 'medo'),
('A ideia de um incêndio em casa me deixa nervoso.', 'medo'),
('O medo de estar em um local com muitas pessoas me deixa tenso.', 'medo'),
('A sensação de que algo está escondido no sótão me apavora.', 'medo'),
('Tenho medo de dirigir em rodovias desconhecidas.', 'medo'),
('O medo de ser rejeitado em um encontro me causa insônia.', 'medo'),
('Sinto medo de assistir a filmes de terror.', 'medo'),
('A ideia de um ataque de abelhas me deixa apreensivo.', 'medo'),
('O medo de ser alvo de críticas me paralisa.', 'medo'),
('A sensação de estar perdido em um labirinto é aterradora.', 'medo'),
('Tenho medo de voar durante uma tempestade.', 'medo'),
('O medo de ser atacado por um animal selvagem me deixa tenso.', 'medo'),
('Sinto medo de confrontar meus traumas do passado.', 'medo'),
('A ideia de um deslizamento de terra me faz evitar áreas montanhosas.', 'medo'),
('O medo de doenças contagiosas me causa ansiedade.', 'medo'),
('A sensação de estar em um lugar assombrado me apavora.', 'medo'),
('Tenho medo de dirigir em estradas sinuosas.', 'medo'),
('O medo de ser vítima de um acidente de trânsito me deixa inquieto.', 'medo'),
('Sinto medo de enfrentar situações de confronto físico.', 'medo'),
('A ideia de um ataque de tubarão me deixa apreensivo.', 'medo'),
('O medo de ser vítima de violência doméstica me causa ansiedade.', 'medo'),
('A sensação de estar em um lugar abandonado à noite é aterradora.', 'medo'),
('Tenho medo de estar em um avião com turbulência.', 'medo'),
('O medo de perder o controle me paralisa.', 'medo'),
('Sinto medo de lugares escuros e fechados.', 'medo'),
('A ideia de um ataque de alienígenas me deixa nervoso.', 'medo'),
('O medo de ser alvo de um ataque cibernético me causa insônia.', 'medo'),
('A sensação de estar preso em um espaço apertado é sufocante.', 'medo'),
('Tenho medo de ser rebaixado no trabalho.', 'medo'),
('O medo de ser diagnosticado com uma doença grave me deixa preocupado.', 'medo'),
('Sinto medo de situações de confronto verbal intensas.', 'medo'),
('A ideia de um ataque de lobisomem me deixa apavorado.', 'medo'),
('O medo de perder tudo em um incêndio me deixa inquieto.', 'medo'),
('A sensação de estar em um local mal-assombrado à noite é aterradora.', 'medo'),
('Tenho medo de pegar um elevador em prédios muito altos.', 'medo'),
('O medo de ser julgado pelos outros me causa ansiedade.', 'medo'),
('Sinto medo de nadar em águas profundas e escuras','medo'),
('eu imploro, não me matem!','medo'),
('tem certeza que não e perigoso?','medo'),
('não tenho certeza se e seguro','medo'),
('tenho que correr pra não me pegarem','medo'),
('socorro! ele queria roubar os meus doces!','medo'),
('esse cara está me perseguindo','medo'),
('não entro lá, e um lugar muito perigoso','medo'),
('este lugar continua assustador','medo'),
('na selva tem muitos animais perigosos','medo'),
('avancem com cautela','medo'),
('este lugar está silencioso de mais, cuidado!','medo'),
('por favor, deixe-me viver!','medo'),
('vou ficar sem mesada se tirar nota baixa','medo'),
('parece que tem olhos nos vigiando','medo'),
('eu temo que a sentença do juiz possa ser negativa','medo'),
('mas essa missão e arriscada','medo'),
('salvem-se quem puder!','medo'),
('meu plano pode ser descoberto','medo'),
('não tive culpa, juro não fui eu','medo'),
('tenho que tomar cuidado com o lobisomem','medo'),
('se eu não achar, ele vai descobrir a verdade','medo'),
('meu deus, ele desapareceu!','medo'),
('tomara que eles não me vejam daqui!','medo'),
('mantenha isso em segredo, se descobrirem estaremos ferrados','medo'),
('por favor, me soltem, eu sou inocente','medo'),
('estou ouvindo passos atrás de mim','medo'),
('eu vou pedir socorro!','medo'),
('cuidado com as curvas na estrada','medo'),
('não sei não, parece perigoso','medo'),
('estou tremendo de medo!','medo'),
('socorro, eu vou cair!','medo'),
('eu não vou ate a floresta negra, e muito perigoso','medo'),
('ouço passos na minha direção','medo'),
('acho que está arriscado de mais','medo'),
('vamos voltar, e muito perigoso','medo'),
('fuja, se não acabaremos mortos','medo'),
('receio por não me livrar desta situação','medo'),
('socorro! ele está armado!','medo'),
('ei cuidado, você vai bater no poste!','medo'),
('socorro, nós estamos afundando','medo'),
('e serio, cuidado com essa arma!','medo'),
('os tubarões estão atacando!','medo'),
('sinto arrepios quando fico sozinho no escuro','medo'),
('calma, eu não estou com o dinheiro','medo'),
('eu acho que estou sendo enganado','medo'),
('ligeiro, temos que fugir depressa','medo'),
('tem um crocodilo selvagem vindo para cá','medo'),
('se ficarmos quietos eles não vão nos achar','medo'),
('fuja! o tigre parece faminto','medo'),
('estou sem saída, preciso de um milagre','medo'),
('tire isso de mim! socorro!','medo'),
('não sei nadar, vou me afogar!','medo'),
('não tenho certeza se e seguro','medo'),
('vou apanhar se meus pais verem meu boletim','medo'),
('não consigo sair daqui!','medo'),
('se sair tão tarde, poderei ser assaltada','medo'),
('não me deixe por favor!','medo'),
('espere, não pode me largar aqui sozinho','medo'),
('temo pela sua segurança','medo'),
('eu te entrego o dinheiro, por favor não me mate!','medo'),
('ele vai levar todo o meu dinheiro','medo'),
('não dirija tão rápido assim','medo'),
('me descobriram, irão me prender!','medo'),
('só espero que não me façam nenhum mal','medo'),
('vou me afogar, me ajudem a sair da água','medo'),
('não estaremos a salvo aqui','medo'),
('não quero nem pensar no que pode acontecer','medo'),
('nessa cidade e uma desgraça atrás da outra','medo'),
('alguem esta me ligando, estou assustado','medo'),
('isso não e remedio, não me matem','medo'),
('eu não confio nele, tenho que ter cautela','medo'),
('muita cautela','medo'),
('vou ser descoberto, meu deus','medo'),
('receio que terei de ir','medo'),
('a noite e muito perigosa','medo'),
('estou estremecendo com essa casa','medo'),
('olha aquela criatura se movendo monstruosamente','medo'),
('não agüento este suspense','medo'),
('afugente os cães','medo'),
('estou chocado e amedrontado com este assassinato brutal','medo'),
('e preciso afugenta com ímpeto este medo do inferno','medo'),
('seu políticos usam suas forças para afugentar e amedrontar o povo','medo'),
('o objetivo disso e apenas me amedrontar mais','medo'),
('isso me apavora','medo'),
('que abominável esse montro!','medo'),
('vamos alarmar a todos sobre a situação','medo'),
('estou amedrontada','medo'),
('estou com muito medo da noite','medo'),
('ele esta me ameaçando a dias','medo'),
('quanta angustia','medo'),
('estou angustiada','medo'),
('angustiadamente vou sair e casa','medo'),
('isso me deixa apavorada','medo'),
('você esta me apavorando','medo'),
('estou desconfiada de você','medo'),
('não confio em você','medo'),
('ate o cachorro está apavorado','medo'),
('estou assustado com as ações do meu colega','medo'),
('agora se sente humilhado, apavorado','medo'),
('assustou a população e provocou mortes','medo'),
('estou com dificuldades para respirar e muito assustado','medo'),
('os policiais se assustaram quando o carro capotou','medo'),
('o trabalhador e assombrado pelo temor do desemprego','medo'),
('este lugar e mal assombrado','medo'),
('estou assombrado pela crise financeira','medo'),
('mesmo aterrorizado lembro de você','medo'),
('aterrorizado e suando frio','medo'),
('um grupo de elefantes selvagens tem aterrorizado vilas','medo'),
('me sinto intimidada pela sua presença','medo'),
('tenho medo de ser advertida novamente','medo'),
('estou correndo o risco de ser advertido','medo'),
('estou correndo riscos de saúde','medo'),
('os riscos são reais','medo'),
('podemos perder muito dinheiro com essa investida','medo'),
('socorro, fui intimado a depor','medo'),
('fui notificado e estou com medo de perde a guarda da minha filha','medo'),
('estou angustiada com meus filhos na rua','medo'),
('e abominável o que fazem com os animais','medo'),
('foi terrível o tigre quase o matou','medo'),
('me advertiram sobre isso','medo'),
('A tristeza às vezes se esconde atrás de um sorriso falso.', 'tristeza'),
('Perder a fé na humanidade pode causar uma profunda tristeza.', 'tristeza'),
('A sensação de estar perdido no mundo pode ser avassaladora.', 'tristeza'),
('A tristeza pode ser um lembrete de nossas vulnerabilidades.', 'tristeza'),
('Ver alguém que amamos sofrer nos enche de tristeza.', 'tristeza'),
('A solidão profunda é uma das formas mais dolorosas de tristeza.', 'tristeza'),
('A tristeza pode nos fazer sentir desconectados do mundo ao nosso redor.', 'tristeza'),
('A sensação de ser incompreendido pode levar à tristeza.', 'tristeza'),
('A tristeza pode nos fazer questionar o propósito da vida.', 'tristeza'),
('Às vezes, a tristeza é uma resposta à perda de um relacionamento.', 'tristeza'),
('A saudade de momentos felizes do passado pode causar tristeza.', 'tristeza'),
('A tristeza pode se transformar em desespero em momentos difíceis.', 'tristeza'),
('A sensação de impotência diante da injustiça pode ser triste.', 'tristeza'),
('A perda de um animal de estimação querido é uma tristeza profunda.', 'tristeza'),
('A tristeza pode ser um lembrete da efemeridade da vida.', 'tristeza'),
('A tristeza pode ser um sintoma de esgotamento emocional.', 'tristeza'),
('A desilusão com pessoas próximas pode causar tristeza intensa.', 'tristeza'),
('A tristeza pode nos fazer sentir como se estivéssemos afundando em um abismo.', 'tristeza'),
('A perda de um emprego pode ser um gatilho para a tristeza financeira.', 'tristeza'),
('A tristeza é uma emoção complexa que faz parte da jornada humana.', 'tristeza')]

# %%
import numpy as np
import pandas as pd

# %%
type(base)
# Out:
# list

# %% [markdown]
# ## Convertendo uma Lista em um  Dataframe

# %%
basenova = pd.DataFrame(base, columns = ['frase','sentimento'])

# %%
basenova
# Out:
#                                                  frase sentimento
# 0                        não precisei pagar o ingresso    alegria
# 1                          se eu ajeitar tudo fica bem    alegria
# 2                       minha fortuna ultrapassa a sua    alegria
# 3                                 sou muito afortunado    alegria
# 4               e benefico para todos esta nova medida    alegria
# ..                                                 ...        ...
# 275  fui notificado e estou com medo de perde a gua...       medo
# 276            estou angustiada com meus filhos na rua       medo
# 277            e abominável o que fazem com os animais       medo
# 278                 foi terrível o tigre quase o matou       medo
# 279                           me advertiram sobre isso       medo
#
# [280 rows x 2 columns]

# %%
basenova.shape
# Out:
# (280, 2)

# %%
#Embraralhando a base
import sklearn
basenova = sklearn.utils.shuffle(basenova)

# %%
basenova
# Out:
#                                                  frase sentimento
# 105                                  meu suco favorito    alegria
# 7                       estou ansiosa pela sua chegada    alegria
# 175                        mas essa missão e arriscada       medo
# 151                         vamos aplaudir o vencedor     alegria
# 39                esta comida me parece muito atraente    alegria
# ..                                                 ...        ...
# 159                   concretizei finalmente meu sonho    alegria
# 10                                    a musica e linda    alegria
# 35   estou tão animada com os preparativos para o c...    alegria
# 40                                    você me completa    alegria
# 1                          se eu ajeitar tudo fica bem    alegria
#
# [280 rows x 2 columns]

# %%
#para acessar um item quando é uma lista
base[1]
# Out:
# ('se eu ajeitar tudo fica bem', 'alegria')

# %%
#para acessar um item quando é um dataframe
basenova.iloc[[1]]
# Out:
#                             frase sentimento
# 7  estou ansiosa pela sua chegada    alegria

# %%
#quantidade de linhas de um dataframe
basenova.shape
# Out:
# (280, 2)

# %%
#quantidade de linhas de uma lista
len(base)
# Out:
# 280

# %%
import seaborn as sns
sns.countplot(x = basenova['sentimento'], label = 'Contagem');

# %% [markdown]
# ## Separar texto do rótulo - O sentimento é o que queremos prever, então fica separado.

# %%
frases = basenova[['frase']]
sentimento = basenova['sentimento'].values

# %%
frases.head()
# Out:
#                                     frase
# 105                     meu suco favorito
# 7          estou ansiosa pela sua chegada
# 175           mas essa missão e arriscada
# 151            vamos aplaudir o vencedor
# 39   esta comida me parece muito atraente

# %%
sentimento
# Out:
# array(['alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'medo', 'alegria',
# ...

# %% [markdown]
# ## Remoção das Stop Words apenas das frases, realmente ver se vale a pena fazer com ou sem.

# %%
#posso criar minha própria lista de stop words
'''stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',
             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',
             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']'''
# Out:
# "stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',\n             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',\n             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']"

# %%
#ou posso fazer o download de uma
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#pegando em portugues
stopwordsnltk = nltk.corpus.stopwords.words('portuguese')

# %%
stopwordsnltk
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
# ...

# %%
#Criando uma função para retirar as stopwords das frases, já que elas vão ter na frase de medo ou alegria
def removestopwords(text):
    textolimpo = " " # cria uma lista vazia
    doc = text.lower() # Transformando em minúsculo
    separado = doc.split() # transforma em lista de palavras
    for palavra in separado: #vai pegando cada palavra da lista
        if palavra not in stopwordsnltk: # compara cada palavra com a lista de stopwords
          textolimpo += palavra + " " #adiciona cada palavraq que não está nas stopwords na frase
    return textolimpo

# %%
fraseteste = "Eu não sei o porquê, mas amo viajar"

# %%
removestopwords(fraseteste)
# Out:
# ' sei porquê, amo viajar '

# %% [markdown]
# ### aplicando a função na base de dados toda

# %%
frases['frase'] = frases['frase'].apply(removestopwords)
# Out:
# <ipython-input-28-31c157ed447f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frases['frase'] = frases['frase'].apply(removestopwords)

# %%
frases
# Out:
#                                     frase
# 105                        suco favorito
# 7                        ansiosa chegada
# 175                     missão arriscada
# 151              vamos aplaudir vencedor
# 39                comida parece atraente
# ..                                    ...
# 159         concretizei finalmente sonho
# 10                          musica linda
# 35    tão animada preparativos casamento
# 40                              completa
# 1                  ajeitar tudo fica bem
#
# [280 rows x 1 columns]

# %% [markdown]
# ##Separar a base de dados, separando 25% da base para ficar para teste

# %%
from sklearn.model_selection import train_test_split
frases_treino, frases_teste, senti_treino, senti_teste = train_test_split(frases, sentimento, test_size=0.25,shuffle=True)

# %%
frases_treino
# Out:
#                                               frase
# 223                        espero façam nenhum mal
# 53                              adoro cabelo macio
# 124                                          grata
# 256                         ate cachorro apavorado
# 163                             correr pra pegarem
# ..                                              ...
# 267   grupo elefantes selvagens aterrorizado vilas
# 79                                      amor lindo
# 185                       ouvindo passos atrás mim
# 204                            acho sendo enganado
# 151                        vamos aplaudir vencedor
#
# [210 rows x 1 columns]

# %%
senti_treino
# Out:
# array(['medo', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'medo', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'medo', 'medo',
#        'alegria', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'alegria', 'medo', 'medo', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'medo', 'medo', 'alegria',
#        'alegria', 'medo', 'medo', 'alegria', 'alegria', 'medo', 'medo',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
# ...

# %%
#essas vou usar para ensinar a IA
frases_treino.shape
# Out:
# (210, 1)

# %%
senti_treino.shape
# Out:
# (210,)

# %%
# com essas vou ver se ela aprendeu
frases_teste.shape
# Out:
# (70, 1)

# %% [markdown]
# ## Agora que nossa base está separada vamos converter nossos textos em números para a Inteligência Artificial. Processo de Vetorização de Palavras

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vocab = basenova['frase'].values

# %%
vocab
# Out:
# array(['meu suco favorito', 'estou ansiosa pela sua chegada',
#        'mas essa missão e arriscada', 'vamos aplaudir o vencedor ',
#        'esta comida me parece muito atraente',
#        'estou sem saída, preciso de um milagre',
#        'alguem esta me ligando, estou assustado',
#        'adoro este doce de frutas', 'a dor esta amenizando finalmente',
#        'estou me sentindo reconfortada hoje', 'amar e maravilhoso',
#        'fiz a adesão ao curso hoje',
#        'não quero nem pensar no que pode acontecer',
#        'finalmente você colocou meu amor em primeiro lugar',
#        'tem certeza que não e perigoso?', 'não sei não, parece perigoso',
#        'estou loucamente apaixonada',
#        'eu estou sorrindo de orelha a orelha',
#        'estou rodeada pelo seu abraço', 'nossa como sou afortunado',
#        'hora de apreciar um bom vinho', 'ficou lindo',
#        'com todo esse charme você irá atrair a todos',
#        'anseio por seus próximos trabalhos',
# ...

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(vocab)
vectorizer.get_feature_names_out()
# Out:
# array(['abominável', 'abraço', 'abundancia', 'abundante', 'acabaremos',
#        'aceita', 'achar', 'achei', 'acho', 'aconchego', 'acontecer',
#        'aconteceu', 'adentro', 'adesão', 'admirada', 'adorei', 'adoro',
#        'advertida', 'advertido', 'advertiram', 'afeição', 'afogar',
#        'afortunado', 'afugenta', 'afugentar', 'afugente', 'afundando',
#        'agir', 'agitar', 'agora', 'agradar', 'agradecida', 'agradeço',
#        'agradável', 'agüento', 'ajeitar', 'ajuda', 'ajudem', 'alarmar',
#        'alcançado', 'alegria', 'alguem', 'alivio', 'alívio', 'amado',
#        'amar', 'ameaçando', 'amedrontada', 'amedrontado', 'amedrontar',
#        'amenizando', 'amiga', 'amigos', 'amistoso', 'amizade', 'amo',
#        'amor', 'amáveis', 'angustia', 'angustiada', 'angustiadamente',
#        'animada', 'animador', 'animais', 'aniversariante', 'aniversário',
#        'anseio', 'ansiosa', 'anuncio', 'ao', 'apaixonada', 'apaixonados',
# ...

# %%
vectorizer.vocabulary_
# Out:
# {'meu': 397,
#  'suco': 582,
#  'favorito': 303,
#  'estou': 287,
#  'ansiosa': 67,
#  'pela': 462,
#  'sua': 579,
#  'chegada': 156,
#  'mas': 387,
#  'essa': 277,
#  'missão': 403,
#  'arriscada': 95,
#  'vamos': 630,
#  'aplaudir': 80,
#  'vencedor': 633,
#  'esta': 279,
#  'comida': 169,
#  'me': 391,
#  'parece': 457,
#  'muito': 410,
#  'atraente': 111,
#  'sem': 550,
#  'saída': 538,
#  'preciso': 492,
#  'de': 212,
#  'um': 625,
#  'milagre': 399,
#  'alguem': 41,
#  'ligando': 368,
#  'assustado': 104,
#  'adoro': 16,
#  'este': 283,
#  'doce': 247,
#  'frutas': 329,
#  'dor': 249,
#  'amenizando': 50,
#  'finalmente': 320,
#  'sentindo': 556,
#  'reconfortada': 521,
#  'hoje': 341,
#  'amar': 45,
#  'maravilhoso': 385,
#  'fiz': 322,
#  'adesão': 13,
#  'ao': 69,
#  'curso': 203,
#  'não': 438,
#  'quero': 513,
#  'nem': 422,
#  'pensar': 466,
#  'no': 427,
#  'que': 507,
#  'pode': 477,
#  'acontecer': 10,
#  'você': 647,
#  'colocou': 165,
#  'amor': 56,
#  'em': 261,
# ...

# %%
frases_transformadas_treino = vectorizer.transform(frases_treino['frase'].values)
frases_transformadas_teste = vectorizer.transform(frases_teste['frase'].values)

# %%
frases_transformadas_treino
# Out:
# <210x658 sparse matrix of type '<class 'numpy.int64'>'
# 	with 606 stored elements in Compressed Sparse Row format>

# %%
frases_transformadas_treino.shape
# Out:
# (210, 658)

# %%
frases_transformadas_teste.shape
# Out:
# (70, 658)

# %% [markdown]
# # Somente agora entra a parte de Inteligência Artificial (Aprendizado de Máquina) - Vamos Usar 2 modelos de Algoritmos diferentes para comparar o desempenho

# %% [markdown]
# ## Modelo DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report
#from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay

# %%
arvore = DecisionTreeClassifier(max_depth=6, criterion='gini')
arvore.fit(frases_transformadas_treino,senti_treino) # aqui estou ensinando para a Máquina
y_pred_arvore = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_arvore = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_arvore)
confusion_matrix(senti_teste,y_pred_arvore)
# Out:
# 0.6428571428571429
# array([[40,  0],
#        [25,  5]])

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_arvore)
print(report) #Mostra as métricas de resultado do modelo
# Out:
#               precision    recall  f1-score   support
#
#      alegria       0.62      1.00      0.76        40
#         medo       1.00      0.17      0.29        30
#
#     accuracy                           0.64        70
#    macro avg       0.81      0.58      0.52        70
# weighted avg       0.78      0.64      0.56        70

# %%
import matplotlib as plt

# %%
ConfusionMatrixDisplay.from_estimator(arvore, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Eu me sinto péssimo quando você não vem']
frase_nova = ['Eu adorei este presente']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_arvore_unica = arvore.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_arvore_unica
# Out:
# array(['alegria'], dtype=object)

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto

# %% [markdown]
# ## Modelo GradientBoostingClassifier

# %%
xgb = GradientBoostingClassifier(n_estimators=3000,min_samples_leaf = 4, learning_rate=0.1, verbose=True) #Aqui configuramos o estimador
xgb.fit(frases_transformadas_treino,senti_treino) #Iniciamos o treinamento
y_pred_xgb = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_xgb = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_xgb)
confusion_matrix(senti_teste,y_pred_xgb)

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_xgb)
print(report) #Mostra as métricas de resultado do modelo

# %%
plot_confusion_matrix(xgb, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
frase_nova = ['Eu me sinto péssimo quando você não vem']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_xgb_unica = xgb.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_xgb_unica

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto

# %% [markdown]
# ## SGDC

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

# %%
sgdc = SGDClassifier(max_iter=3000, tol=1e-3, n_iter_no_change = 20, eta0=0.4, learning_rate = 'adaptive')
sgdc.fit(frases_transformadas_treino,senti_treino) #treinamento
calibrator = CalibratedClassifierCV(sgdc, cv='prefit') #Calibração para prever o percentual futuramente
model_sgdc = calibrator.fit(frases_transformadas_treino,senti_treino) #treinamento com a calibração
y_pred_sgd = model_sgdc.predict(frases_transformadas_teste) # previsões com a nova base
score_sgd = model_sgdc.score(frases_transformadas_teste, senti_teste) #percentual de acerto do modelo com a base de teste
print(score_sgd)
confusion_matrix(senti_teste,y_pred_sgd) #Gera a matriz de confusão

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_sgd)
print(report) #Mostra as métricas de resultado do modelo

# %%
plot_confusion_matrix(model_sgdc, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_sgdc_unica = model_sgdc.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_sgdc_unica

# %%
percentual_acerto = model_sgdc.predict_proba(frase_nova_convertida)
percentual_acerto
